# %% [markdown]
# <a href="https://colab.research.google.com/github/arturbeg/random_google_colabs/blob/master/titanic_eda_and_predictions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Upload your kaggle.json file with the api keys at this step
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-0cd3dbf7-b5e9-4734-822d-3e674af0e5b9" name="files[]" multiple disabled />
#      <output id="result-0cd3dbf7-b5e9-4734-822d-3e674af0e5b9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"arturbegyan98","key":"2d22f892cf866413f9980b223efa5b30"}'}

# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle competitions download -c titanic
# Out:
# ...
#   0% 0.00/59.8k [00:00<?, ?B/s]
# 100% 59.8k/59.8k [00:00<00:00, 22.8MB/s]
# ...
#   0% 0.00/28.0k [00:00<?, ?B/s]
# 100% 28.0k/28.0k [00:00<00:00, 29.5MB/s]
# ...
#   0% 0.00/3.18k [00:00<?, ?B/s]
# 100% 3.18k/3.18k [00:00<00:00, 3.29MB/s]

# %% [markdown]
# ---

# %%
# Out:
# ...
#   0% 0.00/31.2k [00:00<?, ?B/s]
# 100% 31.2k/31.2k [00:00<00:00, 27.9MB/s]
# ...
#   0% 0.00/441k [00:00<?, ?B/s]
# 100% 441k/441k [00:00<00:00, 60.8MB/s]
# ...
#   0% 0.00/450k [00:00<?, ?B/s]
# 100% 450k/450k [00:00<00:00, 63.2MB/s]
# ...
#   0% 0.00/13.1k [00:00<?, ?B/s]
# 100% 13.1k/13.1k [00:00<00:00, 11.7MB/s]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data=pd.read_csv('train.csv')

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# Cabin          687
# Age            177
# Embarked         2
# Fare             0
# Ticket           0
# Parch            0
# SibSp            0
# Sex              0
# Name             0
# Pclass           0
# Survived         0
# PassengerId      0
# dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %%
data.groupby(['Sex', 'Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %%
# Pclass --> Ordinal Feature
pd.crosstab(data.Pclass, data.Survived, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_6039d7aa_ff21_11e9_affa_0242ac1c0002row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6039d7aa_ff21_11e9_affa_0242ac1c0002row0_col1 {
#             background-color:  #cee666;
#             color:  #000000;
#         }    #T_6039d7aa_ff21_11e9_affa_0242ac1c0002row0_col2 {
#             background-color:  #f4fa66;
#             color:  #000000;
#         }    #T_6039d7aa_ff21_11e9_affa_0242ac1c0002row1_col0 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_6039d7aa_ff21_11e9_affa_0242ac1c0002row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6039d7aa_ff21_11e9_affa_0242ac1c0002row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6039d7aa_ff21_11e9_affa_0242ac1c0002row2_col0 {
#             background-color:  #60b066;
#             color:  #000000;
# ...

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass',hue='Survived',data=data,ax=ax[1]) # investigate countplot more
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_33951fa6_ff22_11e9_affa_0242ac1c0002row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_33951fa6_ff22_11e9_affa_0242ac1c0002row0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_33951fa6_ff22_11e9_affa_0242ac1c0002row0_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_33951fa6_ff22_11e9_affa_0242ac1c0002row0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_33951fa6_ff22_11e9_affa_0242ac1c0002row1_col0 {
#             background-color:  #96cb66;
#             color:  #000000;
#         }    #T_33951fa6_ff22_11e9_affa_0242ac1c0002row1_col1 {
#             background-color:  #a3d166;
#             color:  #000000;
#         }    #T_33951fa6_ff22_11e9_affa_0242ac1c0002row1_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
# ...

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=data)
plt.show()

# %%
# age --> continuous feature
print('Oldest Passenger was of:',data['Age'].max(),'Years')
print('Youngest Passenger was of:',data['Age'].min(),'Years')
print('Average Age on the ship:',data['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass","Age", hue="Survived", data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age", hue="Survived", data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()
